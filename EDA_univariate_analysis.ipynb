# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import rcParams
plt.rcParams['figure.figsize'] = (15,15) 
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['xtick.labelsize'] = 'x-large'
plt.rcParams['ytick.labelsize'] = 'x-large'

# %%
df = pd.read_csv (r'C:\Users\Ezha\Downloads\Ijolmt\online_shoppers_intention.csv')

# %%
df = df.astype({'OperatingSystems': object, 'Browser': object, 'Region': object, 'TrafficType': object})

# %%
numericals = ['Administrative', 'Administrative_Duration', 'Informational', 'Informational_Duration', 'ProductRelated', 
              'ProductRelated_Duration', 'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay']
categoricals = ['OperatingSystems', 'Browser', 'Region', 'TrafficType']
categoricals1 = ['VisitorType', 'Weekend', 'Revenue']
timestamps = ['Month']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  object
#  12  Browser                  12330 non-null  object
#  13  Region                   12330 non-null  object
# ...

# %%
features = numericals
for i in range (0, len (features)):
    plt.subplot (2, 5, i+1)
    sns.boxplot (y = df[features[i]], color = 'blue', orient = 'v')
    plt.tight_layout()

# %%
features = numericals
for i in range (0, len (features)):
    plt.subplot(4, 3, i+1)
    sns.distplot (x = df[features[i]], color = 'blue')
    plt.xlabel (features[i])
    plt.tight_layout()

# %%
features = numericals
for i in range (0, len (features)):
    plt.subplot (2, 5, i+1)
    sns.violinplot (y = df[features[i]], color = 'blue')
    plt.tight_layout()

# %%
features = categoricals
for i in range (0, len (features)):
    plt.subplot (2, 5, i+1)
    sns.boxplot (y = df[features[i]], color = 'blue', orient = 'v')
    plt.tight_layout()

# %%
features = categoricals
for i in range (0, len (features)):
    plt.subplot(4, 3, i+1)
    sns.distplot (x = df[features[i]], color = 'blue')
    plt.xlabel (features[i])
    plt.tight_layout()

# %%
df['VisitorType'].hist(figsize=(5,5))
plt.show()

# %%
r = df['Revenue'].value_counts()
mylabels = ["False","True"]

plt.pie(y, labels = mylabels, autopct='%1.1f%%')
plt.show()

# %%
r
# Out:
# False    10422
# True      1908
# Name: Revenue, dtype: int64

# %%
w = df['Weekend'].value_counts()
mylabels = ["False","True"]

plt.pie(y, labels = mylabels, autopct='%1.1f%%')
plt.show()

# %%
w
# Out:
# False    9462
# True     2868
# Name: Weekend, dtype: int64

# %%
df['Month'].hist(figsize=(8,8))
plt.show()
